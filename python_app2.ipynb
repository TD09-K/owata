# %%
# !pip install requests beautifulsoup4
# Out:
# zsh:1: command not found: pip

# %%
# !pip3 install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-2.3.3-cp39-cp39-macosx_11_0_arm64.whl (10.8 MB)
#      |████████████████████████████████| 10.8 MB 6.5 MB/s eta 0:00:01
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#      |████████████████████████████████| 347 kB 22.7 MB/s eta 0:00:01
# Collecting pytz>=2020.1
#   Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#      |████████████████████████████████| 509 kB 15.4 MB/s eta 0:00:01
# Collecting numpy>=1.22.4
#   Downloading numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 25.5 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dozlecorp.love/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# Installing collected packages: tzdata, pytz, numpy, pandas
# Successfully installed numpy-2.0.2 pandas-2.3.3 pytz-2025.2 tzdata-2025.2
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
url = 'https://www.kinokuniya.co.jp/f/dsd-101005021--' 
res = requests.get(url)

soup = BeautifulSoup(res.text, 'html.parser')

book_div = soup.select_one('.list_area_wrap')

books_a_span = book_div.select('a img.mb05,span.sale_price')

pairs = list(zip(books_a_span[0::2],books_a_span[1::2]))
book = pairs[0]

data = []

for book in pairs:
    names, prices = book
    name = names.get( 'alt', '' ).strip()
    price = prices.get_text(strip=True)

    name = name.replace('\u3000', ' ')

    price = int(price.replace('¥', '').replace(',', ''))

    one_data = {'name': name, 'price': price}

    data.append(one_data)


df = pd.DataFrame(data)

df = df.rename(columns={'name':'書籍','price':'価格'})

df.to_csv('books.csv', index=False, encoding='utf-8-sig')
